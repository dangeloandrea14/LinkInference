# %%
import pandas as pd
import os
from io import StringIO
from pandas import json_normalize

# %%
config_file = os.path.join("output","runs","LinkAttack","Citeseer_GCN_edge.json")
with open(config_file, "r") as f:
    text = f.read().strip()

if not text.startswith("["):
    text = "[" + text
if text.endswith(","):
    text = text[:-1]
if not text.endswith("]"):
    text = text + "]"

df = pd.read_json(StringIO(text))

df_expanded = json_normalize(df['parameters'])
df = pd.concat([df.drop(columns='parameters'), df_expanded], axis=1)

cols = list(df.columns)

#cols.insert(2, cols.pop(cols.index('optimizer.parameters.lr')))

df = df[cols[:22]]


display(df)
# Out:
#                      unlearner   dataset    RunTime   PeakRSS_MB  CudaPeak_MB  \
# 0                     Identity  Citeseer   0.000134  2336.394531   764.181641
# 1               GoldModelGraph  Citeseer   0.213044  2453.792969   972.416504
# 2                   Finetuning  Citeseer   0.274074  2539.980469  1020.616699
# 3       SuccessiveRandomLabels  Citeseer  31.520072  2546.304688  1025.054688
# 4                   Finetuning  Citeseer   0.128757  2549.554688  1028.110352
# 5                         eu_k  Citeseer   0.414734  2605.484375  1032.168457
# 6                      NegGrad  Citeseer   0.196394  2605.484375  1032.358398
# 7              AdvancedNegGrad  Citeseer  30.751369  2605.484375  1040.664551
# 8                      Cascade  Citeseer   0.738604  2641.289062  1059.235352
# 9                  BadTeaching  Citeseer  30.557298  2641.289062  1045.354492
# 10                       Scrub  Citeseer  29.990995  2641.289062  1055.051270
# 11            FisherForgetting  Citeseer  34.081514  2746.613281  1059.299316
# 12  SelectiveSynapticDampening  Citeseer  30.018585  2748.472656  1061.128906
# 13                     Cascade  Citeseer  38.114350  2794.140625  1066.603027
# 14                        IDEA  Citeseer   0.932784  2878.078125  1137.998535
# 15                    CGU_edge  Citeseer        NaN          NaN          NaN
# 16                         CEU  Citeseer   4.212822  2975.031250  1174.642090
#
#     sklearn.metrics.accuracy_score.test.unlearned.on_graph:True  \
# 0                                            0.714715
# 1                                            0.725225
# 2                                            0.732733
# 3                                            0.722222
# 4                                            0.729730
# 5                                            0.791291
# 6                                            0.689189
# 7                                            0.702703
# 8                                            0.747748
# 9                                            0.731231
# 10                                           0.734234
# 11                                           0.509009
# 12                                           0.720721
# 13                                           0.720721
# 14                                           0.720721
# 15                                                NaN
# 16                                           0.717718
#
#     sklearn.metrics.accuracy_score.forget.unlearned.on_graph:True  \
# 0                                            0.761337
# 1                                            0.777446
# 2                                            0.771480
# 3                                            0.758950
# 4                                            0.770286
# 5                                            0.801313
# 6                                            0.744630
# 7                                            0.751790
# 8                                            0.779833
# 9                                            0.776850
# 10                                           0.761933
# 11                                           0.557279
# 12                                           0.764320
# 13                                           0.758950
# 14                                           0.770883
# 15                                                NaN
# 16                                           0.764916
#
#     sklearn.metrics.accuracy_score.train.unlearned.on_graph:True  \
# 0                                            0.761587
# 1                                            0.774948
# 2                                            0.775365
# 3                                            0.776200
# 4                                            0.774530
# 5                                            0.799165
# 6                                            0.751566
# 7                                            0.766597
# 8                                            0.783299
# 9                                            0.787474
# 10                                           0.772025
# 11                                           0.564092
# 12                                           0.763257
# 13                                           0.773695
# 14                                           0.769102
# 15                                                NaN
# 16                                           0.762839
#
#     sklearn.metrics.accuracy_score.test.unlearned.on_graph:False  \
# 0                                            0.725225
# 1                                            0.725225
# 2                                            0.738739
# 3                                            0.734234
# 4                                            0.737237
# 5                                            0.798799
# 6                                            0.693694
# 7                                            0.711712
# 8                                            0.749249
# 9                                            0.738739
# 10                                           0.755255
# 11                                           0.545045
# 12                                           0.725225
# 13                                           0.729730
# 14                                           0.720721
# 15                                                NaN
# 16                                           0.717718
#
#     sklearn.metrics.accuracy_score.test.original.on_graph:False  ...  \
# 0                                            0.725225            ...
# 1                                            0.725225            ...
# 2                                            0.725225            ...
# 3                                            0.725225            ...
# 4                                            0.725225            ...
# 5                                            0.725225            ...
# 6                                            0.725225            ...
# 7                                            0.725225            ...
# 8                                            0.725225            ...
# 9                                            0.725225            ...
# 10                                           0.725225            ...
# 11                                           0.725225            ...
# 12                                           0.725225            ...
# 13                                           0.725225            ...
# 14                                           0.725225            ...
# 15                                           0.725225            ...
# 16                                           0.725225            ...
#
#     f1_macro.forget.unlearned.on_graph:True  \
# 0                                  0.667019
# 1                                  0.676375
# 2                                  0.680828
# 3                                  0.678127
# 4                                  0.679934
# 5                                  0.737384
# 6                                  0.640817
# 7                                  0.652715
# 8                                  0.692996
# 9                                  0.696052
# 10                                 0.670508
# 11                                 0.470754
# 12                                 0.670088
# 13                                 0.672787
# 14                                 0.673518
# 15                                      NaN
# 16                                 0.670593
#
#     f1_macro.forget.original.on_graph:True       AUS      UMIA  \
# 0                                 0.667019  0.954410  0.540338
# 1                                 0.667019  0.959005  0.535460
# 2                                 0.667019  0.973649  0.487805
# 3                                 0.667019  0.967466  0.504690
# 4                                 0.667019  0.971196  0.529644
# 5                                 0.667019  1.064551  0.500000
# 6                                 0.667019  0.911434  0.500750
# 7                                 0.667019  0.934308  0.499062
# 8                                 0.667019  0.988566  0.526642
# 9                                 0.667019  0.967819  0.527767
# 10                                0.667019  1.007113  0.502064
# 11                                0.667019  0.771670  0.501126
# 12                                0.667019  0.952509  0.518762
# 13                                0.667019  0.959771  0.502439
# 14                                0.667019  0.955306  0.561538
# 15                                0.667019       NaN       NaN
# 16                                0.667019  0.954029  0.560976
#
#                 LinkTeller unlearn with sampler bfs+:  \
# 0   {'auc': 0.759141565279958, 'ap': 0.91354857039...
# 1   {'auc': 0.7584751929618001, 'ap': 0.9129133640...
# 2   {'auc': 0.7595753205128201, 'ap': 0.9134242341...
# 3   {'auc': 0.758895866038723, 'ap': 0.91344031171...
# 4   {'auc': 0.759521765436943, 'ap': 0.91355373273...
# 5   {'auc': 0.759213108320251, 'ap': 0.91357737542...
# 6   {'auc': 0.7588410845107271, 'ap': 0.9134968944...
# 7   {'auc': 0.7591967556253271, 'ap': 0.9134735371...
# 8   {'auc': 0.759241725536368, 'ap': 0.91353626302...
# 9   {'auc': 0.758392611852433, 'ap': 0.91308839921...
# 10  {'auc': 0.7580271291208791, 'ap': 0.9130864799...
# 11  {'auc': 0.754738602171637, 'ap': 0.91257890191...
# 12  {'auc': 0.7595033686551541, 'ap': 0.9134907386...
# 13  {'auc': 0.759052034275248, 'ap': 0.91351797388...
# 14  {'auc': 0.760346350078492, 'ap': 0.91383431572...
# 15                                                NaN
# 16  {'auc': 0.75956877943485, 'ap': 0.913571482747...
#
#                LinkTeller original with sampler bfs+:  \
# 0   {'auc': 0.75941588173731, 'ap': 0.913608036564...
# 1   {'auc': 0.75972944466248, 'ap': 0.913664947272...
# 2   {'auc': 0.75977155285191, 'ap': 0.913759588763...
# 3   {'auc': 0.760154614730507, 'ap': 0.91375570146...
# 4   {'auc': 0.7590336374934581, 'ap': 0.9135720710...
# 5   {'auc': 0.75983491954474, 'ap': 0.913665718934...
# 6   {'auc': 0.7590193288854, 'ap': 0.913615099701486}
# 7   {'auc': 0.758983352956567, 'ap': 0.91360217887...
# 8   {'auc': 0.759420787545787, 'ap': 0.91359733490...
# 9   {'auc': 0.759783408555729, 'ap': 0.91371245456...
# 10  {'auc': 0.7602813481161691, 'ap': 0.9137231711...
# 11  {'auc': 0.7602061257195181, 'ap': 0.9137105640...
# 12  {'auc': 0.760219207875457, 'ap': 0.91374734536...
# 13  {'auc': 0.759377044086865, 'ap': 0.91362476038...
# 14  {'auc': 0.7598672161172161, 'ap': 0.9137277488...
# 15  {'auc': 0.7599240417320771, 'ap': 0.9137296996...
# 16  {'auc': 0.760128859236002, 'ap': 0.91371389159...
#
#    Link Stealing Attack unlearned 0 exist/non_exist  \
# 0                                          0.896244
# 1                                          0.898977
# 2                                          0.903764
# 3                                          0.906711
# 4                                          0.903835
# 5                                          0.951332
# 6                                          0.891999
# 7                                          0.903477
# 8                                          0.911919
# 9                                          0.898199
# 10                                         0.909554
# 11                                         0.913922
# 12                                         0.896100
# 13                                         0.904030
# 14                                         0.896457
# 15                                              NaN
# 16                                         0.896263
#
#    Link Stealing Attack 0 unlearned forget/non_exist  training_set    data
# 0                                           0.878888           NaN     NaN
# 1                                           0.882063        retain  global
# 2                                           0.889752           NaN     NaN
# 3                                           0.889419           NaN     NaN
# 4                                           0.889827           NaN     NaN
# 5                                           0.951122           NaN     NaN
# 6                                           0.872048           NaN     NaN
# 7                                           0.886648         train     NaN
# 8                                           0.901447           NaN     NaN
# 9                                           0.879978           NaN     NaN
# 10                                          0.895208           NaN     NaN
# 11                                          0.890851           NaN     NaN
# 12                                          0.878459           NaN     NaN
# 13                                          0.886760           NaN     NaN
# 14                                          0.878676         train     NaN
# 15                                               NaN           NaN     NaN
# 16                                          0.878889           NaN     NaN
#
# [17 rows x 22 columns]
